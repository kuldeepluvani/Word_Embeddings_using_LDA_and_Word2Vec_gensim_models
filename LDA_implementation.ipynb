# %%
import sys
import numpy as np
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
from gensim import corpora, models
import gensim
import csv
import pickle as cPickle
from sklearn.externals import joblib
from string import digits
import bz2
import pyLDAvis
import pyLDAvis.gensim

# %%
input_file_name = 'input_tech_data.txt'

# %%
data = []
newlines = []
input_file_name = 'input_tech_data.txt'
with open(input_file_name, 'r') as f:
    data = f.readlines()
for l in data:
    newlines.append(l)

# %%
tokenizer = RegexpTokenizer(r'\w+')

# create English stop words list
en_stop = get_stop_words('en')


texts = []
for i in newlines:
    
    # clean and tokenize document string
    raw = i.lower()
    tokens = tokenizer.tokenize(raw)

    # remove stop words from tokens
    stopped_tokens = [i for i in tokens if not i in en_stop]
    
    # stem tokens
    
    # add tokens to list
    texts.append(stopped_tokens)
    
#Clean data. Some tokenized words end up as just "s" as the word. 
#For example baby's could be split into 'baby', and 's'. 
i = 0
while i < 5:
    i +=1
    for sentence in texts:
        for word in sentence:
            if word  == 's':
                sentence.remove(word)

# %%
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]
lda = gensim.models.ldamulticore.LdaMulticore(corpus, id2word=dictionary,num_topics=, chunksize=30, passes=20, workers=30)


tokens_after_lemmas_and_rm_stopwords = open('tokens_after_lemmas_and_rm_stopwords.txt', 'w')
for item in texts:
    tokens_after_lemmas_and_rm_stopwords.write("%s\n" % item)
    
dictionary.save_as_text('lemmas_nostopwords_with_otherdatacleaning_dictionary_' + input_file_name + '.txt')

corpora.MmCorpus.serialize('lemmas_nostopwords_corpus_'+ input_file_name +'.mm', corpus)
    
joblib.dump(lda, 'ldamodel_'+ input_file_name+ '.pkl')
# Out:
# ['ldamodel_input_tech_data.txt.pkl']

# %%
print(corpus[56])
# Out:
# [(13, 4), (20, 1), (22, 1), (29, 2), (35, 1), (36, 3), (78, 2), (83, 1), (96, 1), (97, 2), (112, 2), (115, 1), (116, 1), (124, 1), (130, 2), (134, 2), (158, 2), (162, 3), (163, 1), (167, 17), (179, 2), (180, 2), (187, 1), (191, 2), (193, 1), (198, 1), (212, 3), (217, 1), (263, 2), (279, 1), (313, 1), (314, 1), (320, 1), (332, 1), (333, 1), (352, 1), (374, 1), (375, 1), (377, 1), (378, 1), (386, 1), (389, 4), (390, 1), (395, 1), (408, 2), (415, 1), (422, 2), (429, 1), (442, 1), (447, 1), (449, 3), (451, 1), (462, 2), (468, 1), (477, 1), (479, 1), (484, 1), (506, 1), (507, 1), (512, 1), (519, 1), (530, 2), (534, 1), (546, 7), (567, 1), (574, 1), (600, 1), (606, 1), (634, 5), (657, 6), (672, 1), (673, 1), (726, 2), (779, 1), (829, 8), (846, 1), (852, 1), (893, 2), (1028, 2), (1076, 1), (1090, 2), (1113, 1), (1173, 1), (1176, 1), (1203, 1), (1212, 1), (1261, 1), (1280, 2), (1286, 2), (1300, 1), (1313, 2), (1329, 1), (1330, 1), (1370, 1), (1384, 1), (1390, 1), (1400, 2), (1404, 1), (1412,
# ...

# %%
dictionary = gensim.corpora.Dictionary.load_from_text('lemmas_nostopwords_with_otherdatacleaning_dictionary_' + input_file_name + '.txt')
corpus = gensim.corpora.MmCorpus('lemmas_nostopwords_corpus_'+ input_file_name +'.mm')
lda = joblib.load('ldamodel_'+ input_file_name + '.pkl')

(lda.print_topics(num_topics=100, num_words=8))
# Out:
# [(0,
#   u'0.021*"statements" + 0.017*"forward" + 0.015*"looking" + 0.012*"company" + 0.012*"transaction" + 0.012*"will" + 0.012*"may" + 0.010*"emc"'),
#  (1,
#   u'0.013*"new" + 0.013*"gan" + 0.012*"diodes" + 0.012*"high" + 0.012*"low" + 0.012*"voltage" + 0.009*"power" + 0.008*"focal"'),
#  (2,
#   u'0.018*"sleep" + 0.012*"mirantis" + 0.009*"carriers" + 0.008*"night" + 0.008*"openstack" + 0.007*"bed" + 0.007*"brain" + 0.006*"will"'),
#  (3,
#   u'0.028*"cpr" + 0.020*"repair" + 0.017*"store" + 0.014*"consulting" + 0.013*"buan" + 0.012*"city" + 0.012*"cell" + 0.012*"phone"'),
#  (4,
#   u'0.017*"certified" + 0.015*"ace" + 0.014*"usa" + 0.013*"pest" + 0.013*"zones" + 0.011*"control" + 0.011*"clark" + 0.010*"ca"'),
#  (5,
#   u'0.012*"ohio" + 0.009*"river" + 0.008*"centurylink" + 0.007*"water" + 0.007*"said" + 0.006*"algae" + 0.006*"hospital" + 0.006*"advanced"'),
#  (6,
# ...

# %%
lda_vis = pyLDAvis.gensim.prepare(lda, corpus, dictionary)
pyLDAvis.display(lda_vis)
# Out:
# c:\python27\lib\site-packages\pyLDAvis\_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el85085950427361073485237"></div>
# <script type="text/javascript">
#
# ...
